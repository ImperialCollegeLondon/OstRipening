# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import os

# %%
def formatFig(xlabel, ylabel, leg, xlim, ylim, loc=1, bbox_to_anchor=None):
    label_font = {'fontname': 'Arial', 'size': 14, 'color': 'black', 'weight': 'bold',
                    'labelpad': 10}
    
    legend = plt.legend(leg, frameon=False,loc=loc, bbox_to_anchor=bbox_to_anchor)
    ax = plt.gca()
    ax.tick_params(direction='in', axis='both', which='major', pad=10)
    
    # Set the rotation and label coordinates for the fraction part
    #ax.yaxis.label.set_rotation(0)
    #ax.yaxis.set_label_coords(-0.19, 0.5)

    # Increase font size and make it bold        
    for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] + ax.get_xticklabels() 
                    + ax.get_yticklabels() + legend.get_texts()):
        item.set_fontsize(14)
        item.set_fontname('Arial')
        item.set_fontweight('bold')
        
    # Remove right and top spines
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)

    ax.set_xlabel(xlabel, **label_font)
    ax.set_ylabel(ylabel, **label_font, rotation=90)
    
    ax.set_ylim(ylim)
    ax.set_xlim(xlim)

    plt.tight_layout()

# %%
MEMORY_DIR_LIST = ["./ostrip_initial_0_PcD_equal_PistonPcRec",
              "./ostrip_initial_0_PcD_equal_PistonPcRec_and_PcI_alpha_070",
              "./ostrip_initial_0_PcD_equal_PistonPcRec_and_PcI_alpha_040",
              "./ostrip_initial_0_PcD_equal_PistonPcRec_and_PcI_alpha_030"]

colors = ['b', 'g', 'k', 'c', 'm', 'y', 'k']
tmax = 0.0
minsat, maxsat = 1.0, 0.0
for i, MEMORY_DIR in enumerate(MEMORY_DIR_LIST):
    timeArray = np.genfromtxt(os.path.join(MEMORY_DIR,'timeArrayOstRipening_bent.dat'),
                              delimiter=',')
    saturation = np.genfromtxt(os.path.join(MEMORY_DIR,'saturationOstRipening_bent.dat'),
                               delimiter=',')
    numberEvents = np.loadtxt(os.path.join(MEMORY_DIR,'numberEventsOstRipening_bent.dat'), 
                            delimiter=',', dtype=int)
    timeArray = timeArray[:-1]
    saturation = saturation[:-1]
    minsat = min(minsat, min(saturation))
    maxsat = max(maxsat, max(saturation))
    tmax = max(tmax, timeArray[-1])

    plt.plot(timeArray/3600, saturation, '-'+colors[i])
    


plt.plot([0.0, tmax/3600], [0.64333, 0.64333], '--r')
xlabel = r'Time ($hrs$)'
ylabel = 'Phase 1 Saturation'
xlim = [0, None]
ylim = [0.6, 0.7]
#ylim = [0.0, 1.0]
#leg = ['Gas clusters', 'Aqueous']
leg = ['alpha = 1.0', 'alpha = 0.7', 'alpha = 0.4', 'alpha = 0.3', 'initial']
formatFig(xlabel, ylabel, leg, xlim, ylim, loc=1, bbox_to_anchor=None)
plt.savefig(f"saturation_time_OstRipening_bent.png", dpi=500)
plt.show()
plt.close()

print(minsat, maxsat)
# Out:
# 0.6427974458560478 0.6446754853518671

# %%
MEMORY_DIR_LIST = ["./ostrip_initial_0_PcD_equal_PistonPcRec",
              "./ostrip_initial_0_PcD_equal_PistonPcRec_and_PcI_alpha_070",
              "./ostrip_initial_0_PcD_equal_PistonPcRec_and_PcI_alpha_040",
              "./ostrip_initial_0_clusterPc_equal_PistonPcRec_and_PcI_alpha_040",
              "./ostrip_initial_0_clusterPc_equal_PistonPcRec_and_PcI_alpha_070"]

colors = ['b', 'g', 'k', 'c', 'm', 'y', 'k']
tmax = 0.0
minsat, maxsat = 1.0, 0.0
for i, MEMORY_DIR in enumerate(MEMORY_DIR_LIST):
    timeArray = np.genfromtxt(os.path.join(MEMORY_DIR,'timeArrayOstRipening_bent.dat'),
                              delimiter=',')
    saturation = np.genfromtxt(os.path.join(MEMORY_DIR,'saturationOstRipening_bent.dat'),
                               delimiter=',')
    numberEvents = np.loadtxt(os.path.join(MEMORY_DIR,'numberEventsOstRipening_bent.dat'), 
                            delimiter=',', dtype=int)
    timeArray = timeArray[:-1]
    saturation = saturation[:-1]
    minsat = min(minsat, min(saturation))
    maxsat = max(maxsat, max(saturation))
    tmax = max(tmax, timeArray[-1])

    plt.plot(timeArray/3600, saturation, '-'+colors[i])
    


plt.plot([0.0, tmax/3600], [0.64333, 0.64333], '--r')
xlabel = r'Time ($hrs$)'
ylabel = 'Phase 1 Saturation'
xlim = [0, None]
ylim = [0.6, 0.7]
#ylim = [0.0, 1.0]
#leg = ['Gas clusters', 'Aqueous']
leg = ['alpha = 1.0', r'modified_$P_{ck}^G$ alpha=0.7', r'modified_$P_{ck}^G$ alpha=0.4', 
       r'modified_$P_{ck}^0$ alpha=0.4', r'modified_$P_{ck}^0$ alpha=0.7', 'initial_Saturation_after_imbibition']
formatFig(xlabel, ylabel, leg, xlim, ylim, loc=1, bbox_to_anchor=None)
plt.savefig(f"saturation_time_OstRipening_bent_1.png", dpi=500)
plt.show()
plt.close()

print(minsat, maxsat)
# Out:
# 0.6079429314989108 0.645729

# %%
MEMORY_DIR_LIST = ["./ostrip_initial_0_PcD_equal_PistonPcRec",
              "./ostrip_initial_0_PcD_equal_PistonPcRec_and_PcI_alpha_070",
              "./ostrip_initial_0_PcD_equal_PistonPcRec_and_PcI_alpha_040"
              #"./ostrip_initial_0_PcD_equal_PistonPcRec_and_PcI_alpha_030"
              ]

colors = ['b', 'g', 'k', 'r', 'm', 'y', 'k']
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()

for i, MEMORY_DIR in enumerate(MEMORY_DIR_LIST):
    print(i)
    timeArray = np.genfromtxt(os.path.join(MEMORY_DIR,'timeArrayOstRipening_bent.dat'),
                              delimiter=',')
    numberEvents = np.loadtxt(os.path.join(MEMORY_DIR,'numberEventsOstRipening_bent.dat'), 
                            delimiter=',', dtype=int)
    #timeArray = timeArray[:-1]
    
    ax1.plot(timeArray/3600, numberEvents[:,0], '-'+colors[i])
    ax2.plot(timeArray/3600, numberEvents[:,1], '--'+colors[i], label='_nolegend_')
    print(numberEvents)


MEMORY_DIR = "./ostrip_initial_Pc_PcD_equal_PistonPcRec"
timeArray = np.genfromtxt(os.path.join(MEMORY_DIR,'timeArrayOstRipening_bent_3.dat'),
                              delimiter=',')
numberEvents = np.loadtxt(os.path.join(MEMORY_DIR,'numberEventsOstRipening_bent_3.dat'), 
                            delimiter=',', dtype=int)
timeArray = timeArray[:-1]
    
ax1.plot(timeArray/3600, numberEvents[:,0], '-'+colors[i+1])
ax2.plot(timeArray/3600, numberEvents[:,1], '--'+colors[i+1], label='_nolegend_')

ax1.tick_params(axis='y', labelcolor='b')
ax2.tick_params(axis='y', labelcolor='r')
ax1.set_xlabel(r'Time ($hrs$)')
ax1.set_ylabel('Number of shrinkage events', color='b')
ax2.set_ylabel('Number of growth events', color='b')
ax2.set_ylim([0, 120])

leg = ['alpha = 1.0', 'alpha = 0.7', 'alpha = 0.4', 'alpha = 0.3', "ripening_effect"]
ax1.legend(leg, frameon=False, loc='center left', bbox_to_anchor=(0.7, 0.7))

# plt.plot([0.0, tmax/3600], [0.64333, 0.64333], '--r')
#xlabel = r'Time ($hrs$)'
#ylabel = 'Phase 1 Saturation'
#xlim = [0, None]
#ylim = [0.6, 0.7]
#ylim = [0, None]
#plt.yscale('log')
#leg = ['Gas clusters', 'Aqueous']

#formatFig(xlabel, ylabel, leg, xlim, ylim, loc=1, bbox_to_anchor=None)
plt.savefig(f"number_of_events_time_OstRipening_bent_1.png", dpi=500)
plt.show()
plt.close()
# Out:
# 0
# [[   0    0]
#  [   0    0]
#  [   0    1]
#  ...
#  [1195   11]
#  [1195   11]
#  [1195   11]]
# 1
# [[   0    0]
#  [   0    0]
#  [   0    2]
#  ...
#  [1243   17]
#  [1243   17]
#  [1243   17]]
# 2
# [[   0    0]
#  [   0    0]
#  [   0    3]
#  ...
#  [1304   39]
#  [1304   39]
#  [1304   39]]

# %%
MEMORY_DIR_LIST = ["./ostrip_initial_0_PcD_equal_PistonPcRec",
              "./ostrip_initial_0_PcD_equal_PistonPcRec_and_PcI_alpha_070",
              "./ostrip_initial_0_PcD_equal_PistonPcRec_and_PcI_alpha_040",
              "./ostrip_initial_0_clusterPc_equal_PistonPcRec_and_PcI_alpha_040",
              "./ostrip_initial_0_clusterPc_equal_PistonPcRec_and_PcI_alpha_070",
              "./ostrip_initial_Pc_PcD_equal_PistonPcRec"]

colors = ['b', 'g', 'k', 'r', 'm', 'y', 'k']
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()

for i, MEMORY_DIR in enumerate(MEMORY_DIR_LIST):
    try:
        timeArray = np.genfromtxt(os.path.join(MEMORY_DIR,'timeArrayOstRipening_bent.dat'),
                                delimiter=',')
        numberEvents = np.loadtxt(os.path.join(MEMORY_DIR,'numberEventsOstRipening_bent.dat'), 
                                delimiter=',', dtype=int)
    except:
        timeArray = np.genfromtxt(os.path.join(MEMORY_DIR,'timeArrayOstRipening_bent_3.dat'),
                                delimiter=',')
        numberEvents = np.loadtxt(os.path.join(MEMORY_DIR,'numberEventsOstRipening_bent_3.dat'), 
                                delimiter=',', dtype=int)
        timeArray = timeArray[:-1]
    
    ax1.plot(timeArray/3600, numberEvents[:,0], '-'+colors[i])
    ax2.plot(timeArray/3600, numberEvents[:,1], '--'+colors[i], label='_nolegend_')
    #print(numberEvents)


ax1.tick_params(axis='y', labelcolor='b')
ax2.tick_params(axis='y', labelcolor='r')
ax1.set_xlabel(r'Time ($hrs$)')
ax1.set_ylabel('Number of shrinkage events', color='b')
ax2.set_ylabel('Number of growth events', color='b')
ax2.set_ylim([0, 300])

leg = ['alpha = 1.0', r'modified_$P_{ck}^G$ alpha=0.7', r'modified_$P_{ck}^G$ alpha=0.4', 
       r'modified_$P_{ck}^0$ alpha=0.4', r'modified_$P_{ck}^0$ alpha=0.7', 'ripening_effect']
ax1.legend(leg, frameon=False, loc='center left', bbox_to_anchor=(0.55, 0.55))

plt.savefig(f"number_of_events_time_OstRipening_bent_2.png", dpi=500)
plt.show()
plt.close()

# %%
MEMORY_DIR_LIST = ["./ostrip_initial_0_PcD_equal_PistonPcRec",
              "./ostrip_initial_0_PcD_equal_PistonPcRec_and_PcI_alpha_070",
              "./ostrip_initial_0_PcD_equal_PistonPcRec_and_PcI_alpha_040",
              "./ostrip_initial_0_clusterPc_equal_PistonPcRec_and_PcI_alpha_040",
              "./ostrip_initial_0_clusterPc_equal_PistonPcRec_and_PcI_alpha_070",
              "./ostrip_initial_Pc_PcD_equal_PistonPcRec"]

conTToOut = np.loadtxt('connectedThroatsToOutlet.dat', delimiter=',', dtype=int)
arrConTToOut = np.zeros(27329, dtype=bool)
arrConTToOut[conTToOut] = True

conTToIn = np.loadtxt('connectedThroatsToInlet.dat', delimiter=',', dtype=int)
arrConTToIn = np.zeros(27329, dtype=bool)
arrConTToIn[conTToIn] = True

conTToExit = np.loadtxt('connectedThroatsToExit.dat', delimiter=',', dtype=int)
arrConTToExit = np.zeros(27329, dtype=bool)
arrConTToExit[conTToExit] = True

colors = ['b', 'g', 'k', 'r', 'm', 'c', 'k']

for i, MEMORY_DIR in enumerate(MEMORY_DIR_LIST):
       try:
              timeArray = np.genfromtxt(os.path.join(MEMORY_DIR,'timeArrayOstRipening_bent.dat'),
                                   delimiter=',')
              clustID = np.loadtxt(os.path.join(MEMORY_DIR,'clustIDOstRipening_bent.dat'),
                                   delimiter=',', dtype=int)
       except:
              timeArray = np.genfromtxt(os.path.join(MEMORY_DIR,'timeArrayOstRipening_bent_3.dat'),
                                   delimiter=',')
              clustID = np.loadtxt(os.path.join(MEMORY_DIR,'clustIDOstRipening_bent_3.dat'),
                                   delimiter=',', dtype=int)
              print(timeArray.shape, clustID.shape)
              #timeArray = timeArray[:-1]

        
       plt.plot(timeArray/3600, ((clustID>=0)&arrConTToIn).sum(axis=1), '-.'+colors[i])
       plt.plot(timeArray/3600, ((clustID>=0)&arrConTToOut).sum(axis=1), '--'+colors[i], 
              label='_nolegend_')
       plt.plot(timeArray/3600, ((clustID>=0)&arrConTToExit).sum(axis=1), '-'+colors[i],
              label='_nolegend_')
       #ax2.plot(timeArray/3600, numberEvents[:,1], '--'+colors[i], label='_nolegend_')
       print(((clustID>=0)&arrConTToIn).sum(axis=1), 
              ((clustID>=0)&arrConTToOut).sum(axis=1), 
              ((clustID>=0)&arrConTToExit).sum(axis=1))


#plt.yaxis.set_major_locator(MaxNLocator(integer=True))
#plt.tick_params(axis='y', labelcolor='b')
xlabel = r'Time ($hrs$)'
ylabel = 'Number of Elements connected to Outlet'
ylim = ([70,200])
xlim =([0, None])
leg = ['alpha = 1.0', r'modified_$P_{ck}^G$ alpha=0.7', r'modified_$P_{ck}^G$ alpha=0.4', 
       r'modified_$P_{ck}^0$ alpha=0.4', r'modified_$P_{ck}^0$ alpha=0.7', 'ripening_effect']
ax1.legend(leg, frameon=False, loc='center left', bbox_to_anchor=(0.55, 0.75))
formatFig(xlabel, ylabel, leg, xlim, ylim, loc=1, bbox_to_anchor=None)

plt.savefig(f"number_of_elements_connected_to_outlet_time_OstRipening_bent_1.png", dpi=500)
plt.show()
plt.close()
# Out:
# [93 93 93 ... 93 93 93] [79 79 79 ... 79 79 79] [172 172 172 ... 172 172 172]
# [93 93 93 ... 93 93 93] [79 79 79 ... 79 79 79] [172 172 172 ... 172 172 172]
# [93 93 93 ... 93 93 93] [79 79 79 ... 79 79 79] [172 172 172 ... 172 172 172]
# [ 93  93 103 ... 102 102 102] [79 79 79 ... 80 80 80] [172 172 182 ... 182 182 182]
# [ 93  93 100 ...  99  99  99] [79 79 79 ... 80 80 80] [172 172 179 ... 179 179 179]
# (4188,) (4187, 27329)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 37
#      33        print(timeArray.shape, clustID.shape)
#      34        #timeArray = timeArray[:-1]
# ---> 37 plt.plot(timeArray/3600, ((clustID>=0)&arrConTToIn).sum(axis=1), '-.'+colors[i])
#      38 plt.plot(timeArray/3600, ((clustID>=0)&arrConTToOut).sum(axis=1), '--'+colors[i],
#      39        label='_nolegend_')
# ...

# %%
clustID[((clustID>=0)&arrConTToOut)].size, ((clustID>=0)&arrConTToOut).sum(axis=1).size
# Out:
# (507101, 6419)

# %%
alphaSat = np.loadtxt('alphaSaturation.dat', delimiter=',')
plt.plot(alphaSat[:,0], alphaSat[:,1], '--b')
xlabel = r'alpha'
ylabel = 'Phase 1 Saturation'
xlim = [0, 1]
ylim = [0.58, 0.65]
#ylim = [0.0, 1.0]
#leg = ['Gas clusters', 'Aqueous']
leg = []
formatFig(xlabel, ylabel, leg, xlim, ylim, loc=1, bbox_to_anchor=None)
plt.savefig(f"alpha_Saturation_OstRipening_bent.png", dpi=500)
plt.show()
plt.close()

# %%
MEMORY_DIR = "./ostrip_initial_0_PcD_equal_PistonPcRec"
timeArray = np.genfromtxt(os.path.join(MEMORY_DIR,'timeArrayOstRipening_bent.dat'),
                              delimiter=',')
timeArray = timeArray[:-1]
timeArray1 = np.genfromtxt(os.path.join(MEMORY_DIR,'timeArrayOstRipening_bent_1.dat'),
                              delimiter=',')
timeArray1 = timeArray1[:-1]
timeArray2 = np.genfromtxt(os.path.join(MEMORY_DIR,'timeArrayOstRipening_bent_2.dat'),
                              delimiter=',')
timeArray2 = timeArray2[:-1]

saturation = np.genfromtxt(os.path.join(MEMORY_DIR,'saturationOstRipening_bent.dat'),
                              delimiter=',')
saturation = saturation[:-1]
saturation1 = np.genfromtxt(os.path.join(MEMORY_DIR,'saturationOstRipening_bent_1.dat'),
                              delimiter=',')
saturation1 = saturation1[:-1]
saturation2 = np.genfromtxt(os.path.join(MEMORY_DIR,'saturationOstRipening_bent_2.dat'),
                              delimiter=',')
saturation2 = saturation2[:-1]

# %%
MEMORY_DIR = "./ostrip_initial_0_PcD_equal_PistonPcRec_and_PcI_alpha_040"
#MEMORY_DIR = "./ostrip_initial_0_PcD_equal_PistonPcRec"
timeArray = np.genfromtxt(os.path.join(MEMORY_DIR,'timeArrayOstRipening_bent.dat'),
                              delimiter=',')
numberEvents = np.loadtxt(os.path.join(MEMORY_DIR,'numberEventsOstRipening_bent.dat'), 
                            delimiter=',', dtype=int)

# %%
numberEvents[numberEvents[:,1]==39]
# Out:
# array([[1293,   39],
#        [1293,   39],
#        [1293,   39],
#        [1293,   39],
#        [1293,   39],
#        [1293,   39],
#        [1293,   39],
#        [1293,   39],
#        [1293,   39],
#        [1293,   39],
#        [1293,   39],
#        [1293,   39],
#        [1293,   39],
#        [1293,   39],
#        [1293,   39],
#        [1293,   39],
#        [1293,   39],
#        [1294,   39],
#        [1294,   39],
#        [1294,   39],
#        [1294,   39],
#        [1294,   39],
#        [1294,   39],
#        [1294,   39],
#        [1294,   39],
#        [1294,   39],
#        [1294,   39],
#        [1294,   39],
#        [1294,   39],
#        [1294,   39],
#        [1294,   39],
#        [1294,   39],
#        [1294,   39],
#        [1294,   39],
#        [1294,   39],
#        [1294,   39],
#        [1294,   39],
#        [1294,   39],
#        [1294,   39],
#        [1294,   39],
#        [1294,   39],
#        [1294,   39],
#        [1294,   39],
# ...

# %%
num_bins = 25

rarray = np.loadtxt('radiiArray_bent.dat', delimiter=',')
bin_edges = np.linspace(rarray.min(), rarray.max(), num_bins+1)
bin_indices = np.digitize(rarray, bin_edges, right=True)


rarrayP = rarray[1:8223]
# bin_edges = np.linspace(rarrayP.min(), rarrayP.max(), num_bins+1)
# bin_indices = np.digitize(rarrayP, bin_edges, right=True)
yyP = np.bincount(bin_indices[1:8223], rarrayP, num_bins+1)/rarray.sum()
#plt.fill_between(bin_edges*1e6, yyP, 0.0, color='red', alpha=0.4)
plt.plot(bin_edges*1e6, yyP, color='red')


rarrayT = rarray[8223:-1]
# bin_edges = np.linspace(rarrayT.min(), rarrayT.max(), num_bins+1)
# bin_indices = np.digitize(rarrayT, bin_edges, right=True)
yyT = np.bincount(bin_indices[8223:-1], rarrayT, num_bins+1)/rarray.sum()
#plt.fill_between(bin_edges*1e6, yyT, 0.0, color='blue', alpha=0.4)
plt.plot(bin_edges*1e6, yyT, color='blue')


# leg = ['time = 0.0 hrs']
# bin_indices = np.digitize(arr, bin_edges, right=True)
# yy = np.bincount(bin_indices, arr, num_bins+1)/arr.sum()
# #xx, yy = f(arr, drV, rV)

# #plt.plot(bin_edges*1e6, np.cumsum(yy0), color='red')
# #plt.plot(bin_edges*1e6, np.cumsum(yy), '--', color='blue')
# plt.fill_between(bin_edges*1e18, np.cumsum(yy0), 0.0, color='red', alpha=0.4)
# plt.fill_between(bin_edges*1e18, np.cumsum(yy), 0.0, facecolor='none', edgecolor='blue', hatch='//')
# leg.append(f'time = {round(timeArray[i+1]/3600,1)} hrs')
leg = ['pore bodies', 'pore throats']
formatFig(r'radius ($\mathbf{\mu m}$)', r'Fraction', leg, 
            [0, None], [0,None], 1)
plt.show()
#plt.savefig(f'bent_pore_throat_radii_distributiom.png', dpi=500)
#plt.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 num_bins = 25
# ----> 3 rarray = np.loadtxt('radiiArray_bent.dat', delimiter=',')
#       4 bin_edges = np.linspace(rarray.min(), rarray.max(), num_bins+1)
#       5 bin_indices = np.digitize(rarray, bin_edges, right=True)
#
# NameError: name 'np' is not defined

# %%
import re
s = '010101101'
re.sub('01', '10', s)
for i in range(len(s)):
    if s[i]=='0' and s[i+1]=='1':
        print(sum(int(s[1:])))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 6
#       4 for i in range(len(s)):
#       5     if s[i]=='0' and s[i+1]=='1':
# ----> 6         print(sum(int(s[1:])))
#
# TypeError: 'int' object is not iterable
